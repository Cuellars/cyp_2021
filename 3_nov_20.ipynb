# %% [markdown]
# <a href="https://colab.research.google.com/github/Cuellars/cyp_2021/blob/main/3_nov_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejemplo1
for i in [1,2,3,5]:
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 5

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
    print(f"el elemento:  {i}")
# Out:
# el elemento:  1
# el elemento:  2
# el elemento:  3
# el elemento:  4
# el elemento:  5

# %%
#ejemplo2
coleccion={"mario":20, "mariana":19, "yessica":14, "luis":18}
for i in coleccion:
  print(f"elemento: {i}")
# Out:
# elemento: mario
# elemento: mariana
# elemento: yessica
# elemento: luis

# %%
coleccion={"mario":20, "mariana":19, "yessica":14, "luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion={"mario":20, "mariana":19, "yessica":14, "luis":18}
for i in coleccion:
  print(f"{i}->{coleccion[i]}")
# Out:
# mario->20
# mariana->19
# yessica->14
# luis->18

# %%
#ejemplo3
email=False
for i in"lore@gmail.com":
  if(i=="@"):
    email=True
if email== True:
     print("el email es correcto")

else:
     print("el email es falso")
# Out:
# el email es correcto

# %%
email=False
miemail=input("tu correo:")
for i in miemail:

  if(i=="@"):
    email=True
    
if email== True:
     print("el email es correcto")

else:
     print("el email es falso")
# Out:
# tu correo:lore@gmail.com
# el email es correcto

# %%
#for-range
for i in range (5):
  print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
  print(f"valor de la variable {i}")
# Out:
# valor de la variable 0
# valor de la variable 1
# valor de la variable 2
# valor de la variable 3
# valor de la variable 4
# valor de la variable 5
# valor de la variable 6
# valor de la variable 7
# valor de la variable 8
# valor de la variable 9

# %%
for i in range (20):
  print(f"valor de la variable {i}")
# Out:
# valor de la variable 0
# valor de la variable 1
# valor de la variable 2
# valor de la variable 3
# valor de la variable 4
# valor de la variable 5
# valor de la variable 6
# valor de la variable 7
# valor de la variable 8
# valor de la variable 9
# valor de la variable 10
# valor de la variable 11
# valor de la variable 12
# valor de la variable 13
# valor de la variable 14
# valor de la variable 15
# valor de la variable 16
# valor de la variable 17
# valor de la variable 18
# valor de la variable 19

# %%
#whileejemplo1

i=1
while i<=10:
  print("Ejecucion"+ str(i))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# ...

# %%
i=1
while i<=10:
  print("Ejecucion"+ str(i))

  i=i+1 #contador, incremanta en 1 a la variable
# Out:
# Ejecucion1
# Ejecucion2
# Ejecucion3
# Ejecucion4
# Ejecucion5
# Ejecucion6
# Ejecucion7
# Ejecucion8
# Ejecucion9
# Ejecucion10

# %%
edad= int(input("introduce tu edad: "))
while edad < 0:
  print("has introducido una edad negativa, intenta de new")
  edad=int(input("intruduce tu edad: "))
  print("gracias por participar, puedes pasar")
  print("edad del aspirante"+ str (edad))
# Out:
# introduce tu edad: -8
# has introducido una edad negativa, intenta de new
# intruduce tu edad: 19
# gracias por participar, puedes pasar
# edad del aspirante19

# %%
edad=int(input("Introduce tu edad:"))
while edad < 10 or edad >= 100:
  print("has introducido una edad negativa, Intentalo de nuevo")
  edad=int(input("introduce tu edad"))
print("gracias por participar.Puede pasar")  
print("edad del aspirante:"+str (edad))
# Out:
# Introduce tu edad:19
# gracias por participar.Puede pasar
# edad del aspirante:19
